# %%
from linear_regress_california import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from pandas import set_option
plt.rcParams['figure.figsize'] = (12,9)

# %%
# Import the dataset.
training_df = pd.read_csv(filepath_or_buffer="https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")



# Scale the label.

training_df["median_house_value"] 

# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
training_df.shape
# Out:
# (17000, 9)

# %%
## Consider total number of rooms as independent variable and house value in thousands of $ as target variable
header = ["total_rooms", "median_house_value"]
## Considering first 1000 training samples for faster implementation
dff=training_df.head(1000) 
dff.to_csv('California.csv', columns = header, index = False)

df = pd.read_csv('California.csv')
regression_estimates,beta ,residuals ,str_error_regression, c_interval = linear_regress(data_set='California.csv')
# Out:
#    total_rooms  median_house_value
# 0       5612.0             66900.0
# 1       7650.0             80100.0
# 2        720.0             85700.0
# 3       1501.0             73400.0
# 4       1454.0             65500.0

# %%
df['regression_estimates'] = regression_estimates



df.to_csv('update_regress_california.csv', index=False)

# %%
test = pd.read_csv('update_regress_california.csv')
print(test)
# Out:
#      total_rooms  median_house_value  regression_estimates
# 0         5612.0             66900.0            170.027825
# 1         7650.0             80100.0            192.135350
# 2          720.0             85700.0            116.961088
# 3         1501.0             73400.0            125.433108
# 4         1454.0             65500.0            124.923268
# ..           ...                 ...                   ...
# 995       6533.0            144400.0            180.018517
# 996       5110.0            112800.0            164.582302
# 997       4397.0            108400.0            156.847922
# 998       4144.0             96000.0            154.103465
# 999       1868.0            307600.0            129.414198
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Conclusion:
#
# The total_rooms feature has only a little predictive power in explaining the mean house price.

# %%
print('Standard error for regression: ', str_error_regression)
# Out:
# Standard error for regression:  72.85727154162075

# %%
print("The regression cofficient value are :",beta)
# Out:
# The regression cofficient value are : [[109.15077482]
#  [207.26618079]]

# %%
print("The desired confidence interval is:",c_interval)
# Out:
# The desired confidence interval is: (3048.978359382805, 3375.951640617195)
